# %% [markdown]
# ### Predictions for ANN

# %%
import pandas as pd
import numpy as np
import pickle
from tensorflow.keras.models import load_model #type: ignore
# Out:
# WARNING:tensorflow:From c:\Users\Aadarsh\miniconda3\envs\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the trained model
model = load_model("model.h5")
# Out:
# WARNING:tensorflow:From c:\Users\Aadarsh\miniconda3\envs\venv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Load the encoder and scaler
with open("onehot_encoding_geography.pkl", "rb") as file:
    onehot_encoder_geo = pickle.load(file)

with open("label_encoder_gender.pkl", "rb") as file:
    label_encoder_gender = pickle.load(file)

with open("scaler.pkl", "rb") as file:
    scaler = pickle.load(file)

# %%
# Example input data
input_data = {
    "CreditScore" : 60,
    "Geography" : "France",
    "Gender" : "Male",
    "Age" : 40,
    "Tenure" : 3,
    "Balance" : 60000,
    "NumOfProducts" : 2,
    "HasCrCard" : 1,
    "IsActiveMember" : 1,
    "EstimatedSalary" : 50000
}

# %%
# OneHot encode Geography
geo_encoded = onehot_encoder_geo.transform([[input_data["Geography"]]]).toarray()
geo_encoded_df = pd.DataFrame(geo_encoded, columns=onehot_encoder_geo.get_feature_names_out(["Geography"]))
# Out:
# c:\Users\Aadarsh\miniconda3\envs\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
geo_encoded_df
# Out:
#    Geography_France  Geography_Germany  Geography_Spain
# 0               1.0                0.0              0.0

# %%
input_df = pd.DataFrame([input_data])
input_df
# Out:
#    CreditScore Geography Gender  Age  Tenure  Balance  NumOfProducts  \
# 0           60    France   Male   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
# Encode Categorical columns
input_df["Gender"] = label_encoder_gender.transform(input_df["Gender"])
input_df
# Out:
#    CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0           60    France       1   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
# Concatination of OneHot encoded column
input_df = pd.concat([input_df.drop("Geography", axis=1), geo_encoded_df], axis=1)

# %%
input_df
# Out:
#    CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0           60       1   40       3    60000              2          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1            50000               1.0                0.0
#
#    Geography_Spain
# 0              0.0

# %%
# Scaling the input data
input_scaled = scaler.transform(input_df)
input_scaled
# Out:
# array([[-6.13995993,  0.91324755,  0.10479359, -0.69539349, -0.25781119,
#          0.80843615,  0.64920267,  0.97481699, -0.87683221,  1.00150113,
#         -0.57946723, -0.57638802]])

# %%
# Prediction churn
prediction = model.predict(input_scaled)
# Out:
# 1/1 [==============================] - 0s 387ms/step

# %%
prediction
# Out:
# array([[0.07468237]], dtype=float32)

# %%
prediction_prob = prediction[0][0]

# %%
prediction_prob
# Out:
# 0.07468237

# %%
if prediction_prob > 0.5:
    print("The Customer is likely to churn")
else:
    print("The Customer is not likely to churn")
# Out:
# The Customer is not likely to churn
